# %% [markdown]
# # CS1112 Project 1
# **Your NetID(s):hl2573**
#
# Write your NetID(s) only; do not write your name(s).

# %% [markdown]
# ## Problem 1 Approximating the square root

# %%
#the table design and value assign
a=float(input('Enter a positive number < 100:'))
print('Build increasingly square rectangles with area', a)
print('-------------------------------------------')
print('No.        Length                 Width')
print('-------------------------------------------')
#caculation
L=a
W=1
print(f'1 {L:20.12f} {W:20.12f}')
L= (L+W)/2
W= a/L
print(f'2 {L:20.12f} {W:20.12f}')
L= (L+W)/2
W= (a/L)
print(f'3 {L:20.12f} {W:20.12f}')
L= (L+W)/2
W= a/L
print(f'4 {L:20.12f} {W:20.12f}')
L= (L+W)/2
W= (a/L)
print(f'5 {L:20.12f} {W:20.12f}')
L= (L+W)/2
W= a/L
print(f'6 {L:20.12f} {W:20.12f}')
L= (L+W)/2
W= (a/L)
print(f'7 {L:20.12f} {W:20.12f}')

print(' ')
#Result#
print(f'The square root of {a:9.6f} is approximatly {W:5.3f}' )
# Out:
# Enter a positive number < 100: 75.6
# Build increasingly square rectangles with area 75.6
# -------------------------------------------
# No.        Length                 Width
# -------------------------------------------
# 1      75.600000000000       1.000000000000
# 2      38.300000000000       1.973890339426
# 3      20.136945169713       3.754293382777
# 4      11.945619276245       6.328679849218
# 5       9.137149562731       8.273915128670
# 6       8.705532345700       8.684132916620
# 7       8.694832631160       8.694819464272
#
# The square root of 75.600000 is approximatly 8.695

# %% [markdown]
# **Does the accuracy of our approximation (at seven averaging steps) appear to change with increasing _a_?**
#
# **The accuracy of our approximation did change with increasing a, as for a<100. I tried 56, which give me an answer accure to 6 decimal place. I tried 66, which give me an answer accure to 5 decimal place. I tried 76, which give me an answer accure to 5 decimal place. I tried 86, which give me an answer accure to 4 decimal place. I tried 96, which give me an answer accure to 4 decimal place. The accurcy is slowly decrease as the number a increase.**

# %% [markdown]
# ## Problem 2 Book Seller

# %%
#assign the value
Cover_price = float(input('Enter the cover price:'))
Number_of_copies = float(input('Enter number of copies:'))
Book_store = str(input('Is this a bookstore? (Y/N)'))

#For book store#
if Book_store == "Y" or Book_store == "y" :
    Discount = float(input('Enter the books tore discount percentage:'))
    Book_cost = Cover_price*Number_of_copies*((100-Discount)/100)
    Shipping_cost = 5+0.95*(Number_of_copies-1)
    Taxes = 0
    Total_cost = Book_cost+Shipping_cost+Taxes
    print(' ')
    print('---------Bookstore bill---------')
    print(f'Book cost: {Book_cost:21.2f}')
    print(f'Shipping cost:{Shipping_cost:18.2f}')
    print(f'Taxes: {Taxes:25.2f}')
    print(f'Total cost: {Total_cost:20.2f}')
#For individul
elif Book_store == "N" or Book_store == "n" :
    Tax = float(input('Enter the tax rate percentage:'))
    Book_cost = Cover_price*Number_of_copies
    Shipping_cost = 5+0.95*(Number_of_copies-1)
    Taxes = (Tax/100)*Book_cost
    Total_cost = Book_cost+Shipping_cost+Taxes
    print(' ')
    print('----Individual customer bill----')
    print(f'Book cost: {Book_cost:21.2f}')
    print(f'Shipping cost:{Shipping_cost:18.2f}')
    print(f'Taxes: {Taxes:25.2f}')
    print(f'Total cost: {Total_cost:20.2f}')
#for people did not enter Y/y/N/n
else:
    print('error, please try again')
# Out:
# Enter the cover price: 253
# Enter number of copies: 10
# Is this a bookstore? (Y/N) n
# Enter the tax rate percentage: 22
#
# ----Individual customer bill----
# Book cost:               2530.00
# Shipping cost:             13.55
# Taxes:                    556.60
# Total cost:              3100.15
